# %%
#practice-->
import pandas as pd
data={'NAME':['Tom','Ram','jack'],'Age':[22,23,24],'Phone_no':[12345,67890,54321],'Email':['abc@gmail.com','asd@gmail.com','cdf@gmail.com']}
df=pd.DataFrame(data)
print(df)
# Out:
#    NAME  Age  Phone_no          Email
# 0   Tom   22     12345  abc@gmail.com
# 1   Ram   23     67890  asd@gmail.com
# 2  jack   24     54321  cdf@gmail.com

# %%
df
# Out:
#    NAME  Age  Phone_no          Email
# 0   Tom   22     12345  abc@gmail.com
# 1   Ram   23     67890  asd@gmail.com
# 2  jack   24     54321  cdf@gmail.com

# %%
#ques2-->
df = pd.read_csv('weather.csv') 
df.shape
# Out:
# (366, 24)

# %%
df.head
# Out:
# <bound method NDFrame.head of            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    11-01-2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1    11-02-2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2    11-03-2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3    11-04-2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4    11-05-2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5    11-06-2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6    11-07-2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7    11-08-2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8    11-09-2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11-10-2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11-11-2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
df.first(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d532360cbb6f> in <module>()
# ----> 1 df.first(5)
#
# C:\Program FilesC\Program Files\lib\site-packages\pandas\core\generic.py in first(self, offset)
#    7156         from pandas.tseries.frequencies import to_offset
#    7157         if not isinstance(self.index, DatetimeIndex):
# -> 7158             raise TypeError("'first' only supports a DatetimeIndex index")
#    7159
#    7160         if len(self.index) == 0:
#
# TypeError: 'first' only supports a DatetimeIndex index

# %%
df.head(5)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11-01-2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11-02-2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11-03-2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11-04-2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11-05-2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11-01-2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11-02-2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11-03-2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11-04-2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11-05-2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5  11-06-2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6  11-07-2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7  11-08-2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8  11-09-2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11-10-2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
df.describe(include='all')
# Out:
#               Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count          366       366  366.000000  366.000000  366.000000   366.000000
# unique         366         1         NaN         NaN         NaN          NaN
# top     11-10-2007  Canberra         NaN         NaN         NaN          NaN
# freq             1       366         NaN         NaN         NaN          NaN
# mean           NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std            NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min            NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%            NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%            NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%            NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max            NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
df.tail(5)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
b=df.loc[0]
b
# Out:
# Date             11-01-2007
# Location           Canberra
# MinTemp                   8
# MaxTemp                24.3
# Rainfall                  0
# Evaporation             3.4
# Sunshine                6.3
# WindGustDir              NW
# WindGustSpeed            30
# WindDir9am               SW
# WindDir3pm               NW
# WindSpeed9am              6
# WindSpeed3pm             20
# Humidity9am              68
# Humidity3pm              29
# Pressure9am          1019.7
# Pressure3pm            1015
# Cloud9am                  7
# Cloud3pm                  7
# Temp9am                14.4
# Temp3pm                23.6
# RainToday                No
# RISK_MM                 3.6
# RainTomorrow            Yes
# Name: 0, dtype: object

# %%
df.describe(include='all')
# Out:
#               Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count          366       366  366.000000  366.000000  366.000000   366.000000
# unique         366         1         NaN         NaN         NaN          NaN
# top     11-10-2007  Canberra         NaN         NaN         NaN          NaN
# freq             1       366         NaN         NaN         NaN          NaN
# mean           NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std            NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min            NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%            NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%            NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%            NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max            NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
#ques1-->
import pandas as pd
a={'name':pd.Series(['Shubham']),
   'age':pd.Series([21]),
   'mail_id':pd.Series(['shubham098089@gmail.com']),
   'phone':pd.Series([1234567890])}
df=pd.DataFrame(a)
df
# Out:
#       name  age                  mail_id       phone
# 0  Shubham   21  shubham098089@gmail.com  1234567890

# %%
b={'name':pd.Series(['sharma']),
    'age':pd.Series([20]),
    'mail_id':pd.Series(['sharma098089@gmail.com']),
    'phone':pd.Series([9876543210])}
df1=pd.DataFrame(b)
df2=df.append(df1)
df2
# Out:
#       name  age                  mail_id       phone
# 0  Shubham   21  shubham098089@gmail.com  1234567890
# 0   sharma   20   sharma098089@gmail.com  9876543210
