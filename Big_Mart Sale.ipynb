# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
df = pd.read_csv('Big_mart.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.size
# Out:
# 110799

# %%
df.describe()
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility     Item_MRP  \
# count  8523.000000       8523.000000      8523.000000  8523.000000
# mean     12.857645          0.352693         0.066132   140.992782
# std       4.226124          0.477836         0.051598    62.275067
# min       4.555000          0.000000         0.000000    31.290000
# 25%       9.310000          0.000000         0.026989    93.826500
# 50%      12.857645          0.000000         0.053931   143.012800
# 75%      16.000000          1.000000         0.094585   185.643700
# max      21.350000          1.000000         0.328391   266.888400
#
#        Outlet_Establishment_Year  Item_Outlet_Sales  Item_Visibility1
# count                8523.000000        8523.000000       8523.000000
# mean                 1997.831867        2181.288914         66.132029
# std                     8.371760        1706.499616         51.597822
# min                  1985.000000          33.290000          0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#Item_weight: 
df.Item_Weight.fillna(df.Item_Weight.mean(),inplace=True)
df.Item_Weight.head(20)
# Out:
# 0      9.300000
# 1      5.920000
# 2     17.500000
# 3     19.200000
# 4      8.930000
# 5     10.395000
# 6     13.650000
# 7     12.857645
# 8     16.200000
# 9     19.200000
# 10    11.800000
# 11    18.500000
# 12    15.100000
# 13    17.600000
# 14    16.350000
# 15     9.000000
# 16    11.800000
# 17     9.000000
# 18    12.857645
# 19    13.350000
# Name: Item_Weight, dtype: float64

# %%
#Outlet_Type:
df.Outlet_Size.fillna('Medium',inplace=True)
df.Outlet_Size.head(20)
# Out:
# 0     Medium
# 1     Medium
# 2     Medium
# 3     Medium
# 4       High
# 5     Medium
# 6       High
# 7     Medium
# 8     Medium
# 9     Medium
# 10    Medium
# 11     Small
# 12    Medium
# 13     Small
# 14      High
# 15     Small
# 16    Medium
# 17    Medium
# 18    Medium
# 19     Small
# Name: Outlet_Size, dtype: object

# %%
#Item_Fat_Content:
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('low fat','Low Fat')
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('LF','Low Fat')
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('reg','Regular')
df['Item_Fat_Content'].head(20)
# Out:
# 0     Low Fat
# 1     Regular
# 2     Low Fat
# 3     Regular
# 4     Low Fat
# 5     Regular
# 6     Regular
# 7     Low Fat
# 8     Regular
# 9     Regular
# 10    Low Fat
# 11    Regular
# 12    Regular
# 13    Regular
# 14    Low Fat
# 15    Regular
# 16    Low Fat
# 17    Regular
# 18    Low Fat
# 19    Low Fat
# Name: Item_Fat_Content, dtype: object

# %%
#Visualization-->
#Univariate Analysis:
plt.hist(x  = 'Item_Weight',  data=df, bins=30)
sns.set(rc={'figure.figsize':(21.0,8.27)})
sns.despine()

# %%
sns.countplot(x  = 'Item_Fat_Content',data=df)
sns.despine()

# %%
sns.distplot(df['Item_Visibility'])
sns.despine()
# Out:
# C:\Program FilesC\Program Files\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(x  = 'Item_Type',data=df)

# %%
sns.distplot(df['Item_MRP'])
sns.despine()
# Out:
# C:\Program FilesC\Program Files\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Item_Outlet_Sales'])
sns.despine()
# Out:
# C:\Program FilesC\Program Files\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Item_MRP'])
sns.despine()
# Out:
# C:\Program FilesC\Program Files\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#Bivariate Analysis:
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.012049  0.024756
# Item_Visibility              -0.012049         1.000000 -0.001315
# Item_MRP                      0.024756        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008301        -0.074834  0.005020
# Item_Outlet_Sales             0.011550        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008301           0.011550
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.regplot(x = 'Item_MRP',y = 'Item_Outlet_Sales',data = df , x_jitter=0.2, scatter_kws={'alpha':0.2},color='blue')

# %%
df['Item_Visibility1'] = df['Item_Visibility']*1000;
sns.regplot(x = 'Item_Visibility',y = 'Item_Outlet_Sales',data = df , scatter_kws={'alpha':0.2},color='red')

# %%
sns.regplot(x = 'Item_Weight',y = 'Item_Outlet_Sales',data = df , x_jitter=0.2, scatter_kws={'alpha':0.2},color='red')

# %%
#Multivariate Analysis:
p = sns.FacetGrid(df, col='Outlet_Establishment_Year',col_wrap=3)
p.map(plt.scatter,'Item_MRP','Item_Outlet_Sales',alpha = 0.2)

# %%
New_Item_Fat_Content = [1 if values == 'Regular' else 0 for values in df.Item_Fat_Content ]
df['Item_Fat_Content'] = New_Item_Fat_Content

# %%
pd.options.display.max_columns= None
df1 = pd.get_dummies(df, columns=['Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type'])
df1.head(10)
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           FDA15     9.300000                 0         0.016047  249.8092
# 1           DRC01     5.920000                 1         0.019278   48.2692
# 2           FDN15    17.500000                 0         0.016760  141.6180
# 3           FDX07    19.200000                 1         0.000000  182.0950
# 4           NCD19     8.930000                 0         0.000000   53.8614
# 5           FDP36    10.395000                 1         0.000000   51.4008
# 6           FDO10    13.650000                 1         0.012741   57.6588
# 7           FDP10    12.857645                 0         0.127470  107.7622
# 8           FDH17    16.200000                 1         0.016687   96.9726
# 9           FDU28    19.200000                 1         0.094450  187.8214
#
#   Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
test = df1['Item_Outlet_Sales']
train = df1.drop(['Item_Outlet_Sales', 'Item_Identifier','Outlet_Identifier'],axis=1)

# %%
x_train , x_test , y_train , y_test = train_test_split(train , test , train_size = 0.82,random_state =42)
# Out:
# C:\Program FilesC\Program Files\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
from sklearn.preprocessing import *
from sklearn.linear_model import LinearRegression
from sklearn.tree import *
from sklearn import model_selection
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import *

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.score(x_test,y_test)
# Out:
# 0.582366940576996

# %%
clf = RandomForestRegressor(n_estimators=10,max_depth=6,random_state=42).fit(train,test)
results = model_selection.cross_val_score(clf, train, test)
results.mean()
# Out:
# 0.592494695910135

# %%
gbr = GradientBoostingRegressor(n_estimators=50)
gbr.fit(x_train,y_train)
pred=gbr.predict(x_test)
gbr.score(x_test,y_test)
# Out:
# 0.611353489428563
